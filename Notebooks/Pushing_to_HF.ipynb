# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_path = '/content/drive/MyDrive/Project1_all_resources/My_model'

tokenizer = AutoTokenizer.from_pretrained(model_path, local_files_only=True)
model = AutoModelForSequenceClassification.from_pretrained(model_path, local_files_only=True)
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
from google.colab import userdata
userdata.get('amrTokenC')
# Out:
# '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'

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model.push_to_hub("DistilBERT-finetuned")
tokenizer.push_to_hub("DistilBERT-finetuned")
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...dwc1y8r/model.safetensors:   6%|6         | 16.7MB /  268MB
# README.md: 0.00B [00:00, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ARG33/DistilBERT-finetuned/commit/2893fb61b2b7540a49c3424d203e4b60e1739b9b', commit_message='Upload tokenizer', commit_description='', oid='2893fb61b2b7540a49c3424d203e4b60e1739b9b', pr_url=None, repo_url=RepoUrl('https://huggingface.co/ARG33/DistilBERT-finetuned', endpoint='https://huggingface.co', repo_type='model', repo_id='ARG33/DistilBERT-finetuned'), pr_revision=None, pr_num=None)
